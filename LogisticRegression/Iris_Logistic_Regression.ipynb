# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from logistic_regression import LogisticRegression

# %% [markdown]
# 鸢尾花数据集，三分类任务

# %%
data = pd.read_csv('data/Iris.csv')
iris_types = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
x_axis = 'PetalLengthCm'
y_axis = 'PetalWidthCm'

for iris_type in iris_types:
    plt.scatter(data[x_axis][data['Species'] == iris_type],
                data[y_axis][data['Species'] == iris_type],
                label=iris_type)
plt.legend()
plt.show()

# %%
num_examples = data.shape[0]
x_train = data[[x_axis, y_axis]].values.reshape((num_examples, 2))
y_train = data['Species'].values.reshape((num_examples, 1))
max_iterations = 1000

logistic_regression = LogisticRegression(x_train, y_train)
thetas, loss_histories = logistic_regression.train(max_iterations)
labels = logistic_regression.unique_labels

plt.plot(range(len(loss_histories[0])), loss_histories[0], label=labels[0])
plt.plot(range(len(loss_histories[1])), loss_histories[1], label=labels[1])
plt.plot(range(len(loss_histories[2])), loss_histories[2], label=labels[2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9688\3533281822.py in <module>
#       5
#       6 logistic_regression = LogisticRegression(x_train, y_train)
# ----> 7 thetas, loss_histories = logistic_regression.train(max_iterations)
#       8 labels = logistic_regression.unique_labels
#       9
#
# d:\ML\ML_Classic_Algorithms\LogisticRegression\logistic_regression.py in train(self, max_iteration)
#      35             current_labels = (self.labels == unique_label).astype(float)
#      36             (current_theta, loss_history) = LogisticRegression.gradient_descent(
# ---> 37                 self.data, current_labels, current_initial_theta, max_iteration)
#      38             self.theta[label_index] = current_theta
#      39             loss_histories.append(loss_history)
#
# d:\ML\ML_Classic_Algorithms\LogisticRegression\logistic_regression.py in gradient_descent(data, labels, current_initial_theta, max_iteration)
#      60                 data, labels, current_theta.reshape(num_features, 1))),
#      61             # 迭代次数
# ---> 62             options={'maxiter': max_iteration}
#      63         )
#      64
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     614         return _minimize_powell(fun, x0, args, callback, bounds, **options)
#     615     elif meth == 'cg':
# --> 616         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     617     elif meth == 'bfgs':
#     618         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1521
#    1522     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
# -> 1523                                   finite_diff_rel_step=finite_diff_rel_step)
#    1524
#    1525     f = sf.fun
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     260     # calculation reduces overall function evaluations.
#     261     sf = ScalarFunction(fun, x0, args, grad, hess,
# --> 262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#     264     return sf
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     138
#     139         self._update_fun_impl = update_fun
# --> 140         self._update_fun()
#     141
#     142         # Gradient evaluation
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# d:\ML\ML_Classic_Algorithms\LogisticRegression\logistic_regression.py in <lambda>(current_theta)
#      48             # 要优化的目标
#      49             lambda current_theta: LogisticRegression.loss_function(
# ---> 50                 data, labels, current_initial_theta.reshape(num_features, 1)),
#      51             # 初始化权重参数
#      52             current_initial_theta,
#
# d:\ML\ML_Classic_Algorithms\LogisticRegression\logistic_regression.py in loss_function(data, labels, theta)
#      72     def loss_function(data, labels, theta):
#      73         num_examples = data.shape[0]
# ---> 74         predictions = LogisticRegression.hypothesis(data, theta)
#      75         y_is_set_loss = np.dot(
#      76             labels[labels == 1].T, np.log(predictions[labels == 1]))
#
# d:\ML\ML_Classic_Algorithms\LogisticRegression\logistic_regression.py in hypothesis(data, theta)
#      83     @staticmethod
#      84     def hypothesis(data, theta):
# ---> 85         predictions = sigmoid(np.dot(data, theta))
#      86         return predictions
#      87
#
# TypeError: 'module' object is not callable
